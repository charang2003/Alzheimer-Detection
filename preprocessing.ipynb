# %%
from PIL import Image
import os
import shutil

# %%
input_dir = r"C:\New folder\VScode\Alzimer-detection\archive\AugmentedAlzheimerDataset\MildDemented"
output_dir = r"C:\New folder\VScode\Alzimer-detection\Data2\MildDemented"
target_size = (200, 190)

# %%
for filename in os.listdir(input_dir):
    # Check for common image extensions (case-insensitive)
    if filename.lower().endswith(('.jpg', '.jpeg', '.png')):
        input_path = os.path.join(input_dir, filename)
        output_path = os.path.join(output_dir, filename)
        
        with Image.open(input_path) as img:
            if img.size != target_size:
                # Resize and save with quality control
                print(f"Resizing {filename} from {img.size} to {target_size}")
                resized_img = img.resize(target_size)
                
                # Save with quality=95 for JPEG, preserve PNG compression
                if filename.lower().endswith(('.jpg', '.jpeg')):
                    resized_img.save(output_path, quality=95, optimize=True)
                else:
                    resized_img.save(output_path)
            else:
                # Copy original without recompression
                print(f"Copying {filename} (already correct size)")
                shutil.copy2(input_path, output_path)
# Out:
# Copying 00046ff7-0fae-4796-9a2b-2df47095bfe6.jpg (already correct size)
# Copying 000cdcc4-3e54-4034-a538-203c8047b564.jpg (already correct size)
# Resizing 0013ad52-8398-4892-9fde-060eb1ae956d.jpg from (180, 180) to (200, 190)
# Copying 0015bdfc-2059-4195-8eff-9c5cf2e2c025.jpg (already correct size)
# Copying 001f15e8-6ad4-4e7a-bc36-b62b984dad69.jpg (already correct size)
# Resizing 001f89e3-8207-4ee4-80d7-711c2acd191a.jpg from (180, 180) to (200, 190)
# Copying 002cb9c1-b160-4c76-b7e4-5fb2f1b527f7.jpg (already correct size)
# Resizing 0033c404-4e68-438d-8312-ba5ba0100d46.jpg from (180, 180) to (200, 190)
# Copying 00372fb8-22c8-4a67-8b10-564caed780fa.jpg (already correct size)
# Copying 00387cfa-b6ce-4eb0-8cc5-9273080c8187.jpg (already correct size)
# Copying 0045bd98-26c5-4bda-b718-8b7ec672f7d6.jpg (already correct size)
# Copying 004dd801-1100-4d89-985d-ef65a22eabab.jpg (already correct size)
# Copying 005a7126-fce8-4bed-be23-d219d300c802.jpg (already correct size)
# ...

# %%
input_dir = r"C:\New folder\VScode\Alzimer-detection\archive\AugmentedAlzheimerDataset\ModerateDemented"
output_dir = r"C:\New folder\VScode\Alzimer-detection\Data2\ModerateDemented"

# %%
for filename in os.listdir(input_dir):
    # Check for common image extensions (case-insensitive)
    if filename.lower().endswith(('.jpg', '.jpeg', '.png')):
        input_path = os.path.join(input_dir, filename)
        output_path = os.path.join(output_dir, filename)
        
        with Image.open(input_path) as img:
            if img.size != target_size:
                # Resize and save with quality control
                print(f"Resizing {filename} from {img.size} to {target_size}")
                resized_img = img.resize(target_size)
                
                # Save with quality=95 for JPEG, preserve PNG compression
                if filename.lower().endswith(('.jpg', '.jpeg')):
                    resized_img.save(output_path, quality=95, optimize=True)
                else:
                    resized_img.save(output_path)
            else:
                # Copy original without recompression
                print(f"Copying {filename} (already correct size)")
                shutil.copy2(input_path, output_path)
# Out:
# Copying 001ef5a6-893b-4ede-9cf8-60b7fb94a541.jpg (already correct size)
# Copying 0021740c-fbc2-405c-b0d7-0c7176217933.jpg (already correct size)
# Resizing 0021fe1e-7a94-40f5-951c-376999c87d98.jpg from (180, 180) to (200, 190)
# Copying 003304b2-5091-4342-93d8-1720afca671e.jpg (already correct size)
# Copying 003394e7-5db3-40fb-8168-e4141dca49bd.jpg (already correct size)
# Copying 003c36ee-8c43-41ce-b5e5-90622644bba5.jpg (already correct size)
# Copying 005c6a8f-ee80-4d61-af35-83b1264badcd.jpg (already correct size)
# Copying 006f96cd-965a-46d7-b0f5-522587addf5f.jpg (already correct size)
# Copying 00965011-ba74-42f9-bd30-8fdabfd3ae82.jpg (already correct size)
# Copying 009f541f-93bc-4299-a24a-63809bf11a24.jpg (already correct size)
# Copying 00a4080b-0cea-436f-9c97-031ee6d3b5f5.jpg (already correct size)
# Copying 00c13721-c182-4bab-8315-ecece13768a2.jpg (already correct size)
# Copying 00c4466b-2eba-49c7-9809-83787aabb4cd.jpg (already correct size)
# ...

# %%
input_dir = r"C:\New folder\VScode\Alzimer-detection\archive\AugmentedAlzheimerDataset\NonDemented"
output_dir = r"C:\New folder\VScode\Alzimer-detection\Data2\NonDemented"

# %%
for filename in os.listdir(input_dir):
    # Check for common image extensions (case-insensitive)
    if filename.lower().endswith(('.jpg', '.jpeg', '.png')):
        input_path = os.path.join(input_dir, filename)
        output_path = os.path.join(output_dir, filename)
        
        with Image.open(input_path) as img:
            if img.size != target_size:
                # Resize and save with quality control
                print(f"Resizing {filename} from {img.size} to {target_size}")
                resized_img = img.resize(target_size)
                
                # Save with quality=95 for JPEG, preserve PNG compression
                if filename.lower().endswith(('.jpg', '.jpeg')):
                    resized_img.save(output_path, quality=95, optimize=True)
                else:
                    resized_img.save(output_path)
            else:
                # Copy original without recompression
                print(f"Copying {filename} (already correct size)")
                shutil.copy2(input_path, output_path)
# Out:
# Resizing 00005576-2b76-44ca-8572-a5057201433f.jpg from (180, 180) to (200, 190)
# Copying 0007d7c8-609f-4339-b810-727535907c42.jpg (already correct size)
# Resizing 00126637-9d0c-4261-b79d-b6897ba3f4af.jpg from (180, 180) to (200, 190)
# Copying 0016c2ee-28b3-4e43-988a-09192f039c8d.jpg (already correct size)
# Copying 0018f6e9-4716-4f8d-aad6-b9bc1b40b255.jpg (already correct size)
# Copying 00190c87-a639-417d-a6d9-bae6a9e68207.jpg (already correct size)
# Copying 002a24a5-fce1-47df-9169-0efafbfd6447.jpg (already correct size)
# Resizing 003b999c-62d5-4d24-bdfc-1476d3a4355f.jpg from (180, 180) to (200, 190)
# Resizing 003f70c6-da04-44ee-978e-54fcd2af64be.jpg from (180, 180) to (200, 190)
# Copying 00454d40-3356-4396-a7b7-31bb491f14df.jpg (already correct size)
# Copying 0048efe4-d51d-453c-acaa-3cd6d3f49e50.jpg (already correct size)
# Copying 00511f82-0e15-4677-b2da-06a1334eb2d0.jpg (already correct size)
# ...

# %%
input_dir = r"C:\New folder\VScode\Alzimer-detection\archive\AugmentedAlzheimerDataset\VeryMildDemented"
output_dir = r"C:\New folder\VScode\Alzimer-detection\Data2\VeryMildDemented"

# %%
for filename in os.listdir(input_dir):
    # Check for common image extensions (case-insensitive)
    if filename.lower().endswith(('.jpg', '.jpeg', '.png')):
        input_path = os.path.join(input_dir, filename)
        output_path = os.path.join(output_dir, filename)
        
        with Image.open(input_path) as img:
            if img.size != target_size:
                # Resize and save with quality control
                print(f"Resizing {filename} from {img.size} to {target_size}")
                resized_img = img.resize(target_size)
                
                # Save with quality=95 for JPEG, preserve PNG compression
                if filename.lower().endswith(('.jpg', '.jpeg')):
                    resized_img.save(output_path, quality=95, optimize=True)
                else:
                    resized_img.save(output_path)
            else:
                # Copy original without recompression
                print(f"Copying {filename} (already correct size)")
                shutil.copy2(input_path, output_path)
# Out:
# Copying 0001b959-d622-4311-acab-84633370c892.jpg (already correct size)
# Copying 0003659d-f8db-4ce4-9230-2ba24506df68.jpg (already correct size)
# Copying 000a074f-a3a5-4c70-8c94-d7ed7bbe7018.jpg (already correct size)
# Copying 000b7abc-2404-411d-a46d-467ec55b7795.jpg (already correct size)
# Resizing 000dea20-ea76-4248-a45d-4119f0bc5ccc.jpg from (180, 180) to (200, 190)
# Copying 000efebb-d4ae-449a-ab10-5e74afa79ef9.jpg (already correct size)
# Copying 000f173f-ebd5-4ef7-b4d4-6cf80cf754b5.jpg (already correct size)
# Copying 0020ed3a-2b5f-4e46-9b96-97484c10a88c.jpg (already correct size)
# Copying 002149f6-8f25-4b27-9d7a-d059f3966676.jpg (already correct size)
# Copying 00255a89-4920-4ac5-b9e9-01430c35ce09.jpg (already correct size)
# Copying 0034d555-157e-404a-8ed4-62e4f05dac7e.jpg (already correct size)
# Copying 0040f18a-c50d-4651-97bf-840c650f3d23.jpg (already correct size)
# Resizing 004a0f62-e3fa-4a4b-afe1-d2c84027db9f.jpg from (180, 180) to (200, 190)
# ...
